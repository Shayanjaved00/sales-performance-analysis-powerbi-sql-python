# %%
import pandas as pd

# %%
df = pd.read_csv("sales_project_day1.csv")

# %%
df.head()
# Out:
#    order_id        date customer       city product  quantity  price
# 0         1  2024-01-01      Ali     Lahore  Laptop         1  90000
# 1         2  2024-01-02     Sara    Karachi   Phone         2  50000
# 2         3  2024-01-03    Ahmed  Islamabad  Tablet         1  30000
# 3         4  2024-01-04      Ali     Lahore   Phone         3  50000
# 4         5  2024-01-05     Sara    Karachi  Laptop         1  90000

# %%
df.isnull().sum()
# Out:
# order_id    0
# date        0
# customer    0
# city        0
# product     0
# quantity    0
# price       0
# dtype: int64

# %%
df["revenue"] = df["quantity"] * df["price"]

# %%
df.groupby("city")["revenue"].sum()
# Out:
# city
# Islamabad    120000
# Karachi      290000
# Lahore       420000
# Name: revenue, dtype: int64

# %%
df.groupby("product")["revenue"].sum()
# Out:
# product
# Laptop    360000
# Phone     350000
# Tablet    120000
# Name: revenue, dtype: int64

# %%
import matplotlib.pyplot as plt

df.groupby("city")["revenue"].sum().plot(kind="bar")
plt.title("Revenue by City")
plt.show()
